# %% [markdown]
# <a href="https://colab.research.google.com/github/choyoungeun/Numerical-Methods/blob/main/Bisect_Method.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![aa1.png](data:image/png;base64,...)

# %% [markdown]
# ![aa2.png](data:image/png;base64,...)

# %%
import numpy as np

print("exp(0)", np.exp(0))
print("exp(1)", np.exp(1))
print("exp(-1)", np.exp(-1))
# Out:
# exp(0) 1.0
# exp(1) 2.718281828459045
# exp(-1) 0.36787944117144233

# %%
import numpy as np

def func_f(c):
  ff= (667.38/c) * (1 - np.exp(-0.146843 * c)) - 40
  return ff

print("{} -> func_f() : {}" .format(4, func_f(4)))
print("{} -> func_f() : {}" .format(8, func_f(8)))
print("{} -> func_f() : {}" .format(12, func_f(12)))
print("{} -> func_f() : {}" .format(16, func_f(16)))
print("{} -> func_f() : {}" .format(20, func_f(20)))
# Out:
# 4 -> func_f() : 34.114889382320015
# 8 -> func_f() : 17.65345263517886
# 12 -> func_f() : 6.066949962931268
# 16 -> func_f() : -2.2687542080397662
# 20 -> func_f() : -8.400624408141017

# %% [markdown]
# ![aa3-5.png](data:image/png;base64,...)

# %% [markdown]
# ![aa4.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np


def func_f(x):
  ff= np.sin(10*x) + np.cos(3*x);
  return ff
  

x=4.25
x=4.229

print("func_f()", func_f(x))

xx = np.linspace(4.2, 4.3,500)
yy = [func_f(b) for b in xx]
'''
fig = plt.figure(figsize=(20,6))
ax = fig.add_subplot(1, 1, 1)
'''
plt.plot(xx, yy)
plt.show()
# Out:
# func_f() 0.00010524317999882626

# %% [markdown]
# ![aa3.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![aa5.png](data:image/png;base64,...)

# %% [markdown]
# ![aa6.png](data:image/png;base64,...)

# %%
import numpy as np

def func_f(c):
  ff= (667.38/c) * (1 - np.exp(-0.146843 * c)) - 40
  return ff

def func_f2(x):
  ff= x**10 - 1
  return ff


xl = 0.5
xu = 50
xr = xu
es = 0.005
imax = 100
iter = 0


while True:
  xrold = xr
  xr = (xl + xu) / 2
  iter = iter + 1

  if xr != 0 :
    ea= abs((xr - xrold) / xr) * 100

  test = func_f(xl) * func_f(xr)

  if test < 0 :
    xu = xr
  elif test > 0 :
    xl = xr
  else :
    ea = 0
 
  print("iter[{}] xl[{}], xu[{}], xr[{}], ea[{}], es[{}]" .format(iter, xl, xu, xr, ea, es))

  if ea < es or iter >= imax :
    break;

Bisect = xr #indent 에 주의하자...
print(">>> Bisect", Bisect)
# Out:
# iter[1] xl[0.5], xu[25.25], xr[25.25], ea[98.01980198019803], es[0.005]
# iter[2] xl[12.875], xu[25.25], xr[12.875], ea[96.11650485436894], es[0.005]
# iter[3] xl[12.875], xu[19.0625], xr[19.0625], ea[32.459016393442624], es[0.005]
# iter[4] xl[12.875], xu[15.96875], xr[15.96875], ea[19.373776908023483], es[0.005]
# iter[5] xl[14.421875], xu[15.96875], xr[14.421875], ea[10.725893824485373], es[0.005]
# iter[6] xl[14.421875], xu[15.1953125], xr[15.1953125], ea[5.089974293059126], es[0.005]
# iter[7] xl[14.421875], xu[14.80859375], xr[14.80859375], ea[2.6114481667106304], es[0.005]
# iter[8] xl[14.615234375], xu[14.80859375], xr[14.615234375], ea[1.3229987972738206], es[0.005]
# iter[9] xl[14.7119140625], xu[14.80859375], xr[14.7119140625], ea[0.6571523398606041], es[0.005]
# iter[10] xl[14.76025390625], xu[14.80859375], xr[14.76025390625], ea[0.3275000827020411], es[0.005]
# iter[11] xl[14.76025390625], xu[14.784423828125], xr[14.784423828125], ea[0.16348233895338277], es[0.005]
# ...

# %% [markdown]
# ![aa7.png](data:image/png;base64,...)

# %%
import numpy as np

def func_f(x):
  ff= x**10 - 1
  return ff

print("{} -> func_f() : {}" .format(0, func_f(0)))
print("{} -> func_f() : {}" .format(1, func_f(1)))
print("{} -> func_f() : {}" .format(2, func_f(20)))
# Out:
# 0 -> func_f() : -1
# 1 -> func_f() : 0
# 2 -> func_f() : 10239999999999

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np


def func_f(x):
  ff= x**10 - 1
  return ff

x=1

print("func_f()", func_f(x))

xx = np.linspace(0, 2.1, 500)
yy = [func_f(b) for b in xx]

fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(1, 1, 1)

plt.plot(xx, yy)
plt.show()
# Out:
# func_f() 0
