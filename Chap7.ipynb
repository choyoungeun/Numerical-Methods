# %% [markdown]
# <a href="https://colab.research.google.com/github/choyoungeun/Numerical-Methods/blob/main/Chap7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Synthetic division**. Several computer algorithms (based on both synthetic division and other methods) are available for performing the operation.

# %% [markdown]
# ![q6.png](data:image/png;base64,...)

# %%
for i in range(5, 0,-1):
  print(f"{i}")
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
a=[1,2,3]
n=2
r=a[n]

a[1]
# Out:
# 2

# %%
# divide function f(x) = (x-4)(x+6) = x**2 + 2*x - 24
# by the factor  x-4

t = 3
a = [-24, 2, 1] # f(x) 각 term들의 계수를 입력
n = 2
r = a[n]
a[n] = 0

for i in range(n-1, -1, -1):
  s = a[i]
  a[i] = r
  r = s + r * t 
  print(f"s:{s}, a[{i}] : {a[i]}, r : {r}")
# Out:
# s:2, a[1] : 1, r : 5
# s:-24, a[0] : 5, r : -9

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np
 func_f(x):
  ff= x**2 + 2*x - 24
  return ff

print("{} -> func_f() : {}" .format(4, func_f(4)))
print("{} -> func_f() : {}" .format(-6, func_f(-6)))

xx = np.linspace(-8, 10, 300)
yy = [func_f(b) for b in xx]

fig = plt.figure(figsize=(10,6))

plt.plot(xx, yy)
plt.show()
# Out:
# 4 -> func_f() : 0
# -6 -> func_f() : 0

# %% [markdown]
# The subroutine in **Fig. 7.**2 addresses the more general problem of dividing an **n**th-order polynomial a by an **m**th-order polynomial **d**.
# The result is an **(n - m)**th-order polynomial **q**, with an **(m - 1)**th-order polynomial as the remainder.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![q3.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![q2.png](data:image/png;base64,...)

# %%
# Muller's Method
# f(x) = x**3 - 13*x - 12
# x0 = 4.5, x1 = 5.5, x2 = 5
# roots are -3, -1, 4

#SUB Muller(xr, h, eps, maxit)

import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np
import math

def func_f(x):
  ff= x**3 - 13*x - 12
  return ff

print("{} -> func_f() : {}" .format(4, func_f(4)))
print("{} -> func_f() : {}" .format(-1, func_f(-1)))
print("{} -> func_f() : {}" .format(-3, func_f(-3)))

xx = np.linspace(-5, 5, 300)
yy = [func_f(b) for b in xx]

fig = plt.figure(figsize=(20,6))

plt.plot(xx, yy)
plt.show()
# Out:
# 4 -> func_f() : 0
# -1 -> func_f() : 0
# -3 -> func_f() : 0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![q9.png](data:image/png;base64,...)

# %%
import math

# Muller's Method
# f(x) = x**3 - 13*x - 12
# x0 = 4.5, x1 = 5.5, x2 = 5
# roots are -3, -1, 4 -> (x+3)(x+1)(x-4)

def func_f(x):
  ff= x**3 - 13*x - 12
  return ff

xr = 5
h = 0.1
eps = 0.00000000001
maxit = 100

x2 = xr
x1 = xr + h*xr
x0 = xr - h*xr
print("---------------------------------")
print(f"x0 : {x0}, x1 : {x1}, x2 : {x2}")
print("---------------------------------")
iter = 0

while True :
  iter = iter + 1
  h0 = x1 - x0
  h1 = x2 - x1
  d0 = (func_f(x1) - func_f(x0)) / h0
  d1 = (func_f(x2) - func_f(x1)) / h1
  a =(d1 - d0) / (h1 + h0)
  b = a*h1 + d1
  c = func_f(x2)
  rad = math.sqrt(b*b - 4*a*c)
  if abs(b+rad) > abs(b-rad) :
    den = b + rad
  else :
    den = b - rad	
  dxr = -2*c / den
  xr = x2 + dxr
  print( f"Iter : {iter}, xr : {xr}, dxr : {dxr}")
  if abs(dxr) < eps*xr or iter >= maxit :
    break;
  x0 = x1
  x1 = x2
  x2 = xr
print("")
print(f"xr : {xr}")
# Out:
# ---------------------------------
# x0 : 4.5, x1 : 5.5, x2 : 5
# ---------------------------------
# Iter : 1, xr : 3.9764870422406546, dxr : -1.0235129577593454
# Iter : 2, xr : 4.001050498815179, dxr : 0.02456345657452424
# Iter : 3, xr : 4.000000705270523, dxr : -0.0010497935446562797
# Iter : 4, xr : 4.000000000000497, dxr : -7.052700251366754e-07
# Iter : 5, xr : 4.0, dxr : -4.973799150489559e-13
#
# xr : 4.0

# %% [markdown]
# ![q1.png](data:image/png;base64,...)
